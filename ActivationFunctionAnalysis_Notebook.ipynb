# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
# Tanh function

# %%
y=sin(in)

# %%
# in_array = np.linspace(-np.pi*4, np.pi*4, 24)
in_array =np.arange(0,2*np.pi,1)   # start,stop,step

out_array_t = np.tanh(in_array)
diff=np.diff(out_array_t)  
print("in_array : ", in_array)
print("\nout_array : ", out_array_t)
  
# red for numpy.cosh()
plt.plot(in_array, out_array_t, color = 'red', marker = "o")
plt.title("numpy.tanh()")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# in_array :  [0. 1. 2. 3. 4. 5. 6.]
#
# out_array :  [0.         0.76159416 0.96402758 0.99505475 0.9993293  0.9999092
#  0.99998771]

# %%
## Sine

# %%
# in_array = np.linspace(-np.pi, np.pi, 24)
in_array= np.arange(0,4*np.pi,0.1)   # start,stop,step

out_array = np.sin(in_array)
diff=np.diff(out_array)  
# print("in_array : ", in_array)
# print("\nout_array : ", out_array)
  
# red for numpy.cosh()
plt.plot(in_array, out_array, color = 'Yellow', marker = "o")
plt.title("numpy.sin()")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
out_array_t = np.tanh(in_array)

out_array_s = np.sin(in_array)

plt.plot(in_array, out_array_s, color = 'Yellow', marker = "o",label='sinh')
plt.plot(in_array, out_array_t, color = 'red', marker = "*",label='tanh')
plt.grid()
plt.title('sinh and tanh functions')
plt.legend(framealpha=1, frameon=True);

# %%
out_array_t = np.tanh(in_array)
out_array_s = np.sin(in_array)

out_array_sum = np.tanh(in_array)+ np.sin(in_array)
sum_diff = np.diff(np.tanh(in_array))+np.diff(np.sin(in_array))

plt.plot(in_array, out_array_s, color = 'orange', marker = "*",label='sinh')
plt.plot(in_array, out_array_t, color = 'red', marker = "*",label='tanh')
plt.plot(in_array, out_array_sum, color = 'blue', marker = "o",label='sinh+tanh')
plt.plot(in_array[:-1], sum_diff, color = 'purple', marker = "o",label='diff of sin+tanh')


plt.grid()
plt.title('sin and tanh functions')
plt.legend(framealpha=1, frameon=True);

# %%
plt.plot(in_array, out_array, color = 'blue', marker = "o",label='sin')
plt.legend(framealpha=1, frameon=True);
plt.grid()
plt.title('sin functions')
# Out:
# Text(0.5, 1.0, 'sin functions')

# %%
plt.plot(in_array, out_array_sum, color = 'blue', marker = "o",label='sin+tanh')
plt.legend(framealpha=1, frameon=True);
plt.grid()
plt.title('Sum of sinh and tanh functions')
# Out:
# Text(0.5, 1.0, 'Sum of sinh and tanh functions')

# %%
plt.plot(in_array[:-1], sum_diff, color = 'purple', marker = "o",label='Diff of sin+tanh')
plt.legend(framealpha=1, frameon=True);
plt.grid()
plt.title('Differential of sum of sin + tanh functions')
# Out:
# Text(0.5, 1.0, 'Differential of sum of sin + tanh functions')

# %%
in_array = np.linspace(-np.pi, np.pi, 24)

out_array1 = np.tanh(in_array)
out_array2 = np.cosh(in_array)
#adding tanh and sinh
sum_diff = np.diff(np.tanh(in_array))+np.diff(np.cosh(in_array))
out_array = out_array1+ out_array2
diff_tanh=np.diff(out_array)
print("in_array : ", in_array)
print("\nout_array : ", diff_tanh)
  
# red for numpy.cosh()
plt.plot(in_array, out_array2, color = 'red', marker = "o")
plt.title("differential of cosh+tanh")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# in_array :  [-3.14159265 -2.86841068 -2.59522871 -2.32204674 -2.04886477 -1.7756828
#  -1.50250083 -1.22931886 -0.95613689 -0.68295492 -0.40977295 -0.13659098
#   0.13659098  0.40977295  0.68295492  0.95613689  1.22931886  1.50250083
#   1.7756828   2.04886477  2.32204674  2.59522871  2.86841068  3.14159265]
#
# out_array :  [-2.75635254 -2.09111118 -1.5818666  -1.18968851 -0.88405179 -0.64046777
#  -0.43882857 -0.2628622  -0.10146847  0.04787489  0.1767368   0.27149563
#   0.32832733  0.36243944  0.3996919   0.46252796  0.56526359  0.71772734
#   0.93023811  1.21693785  1.59781862  2.10040709  2.76175524]

# %%
in_array = np.linspace(-np.pi, np.pi, 24)
out_array1 = np.tanh(in_array)

out_array2 = np.sinh(in_array)
#adding tanh and sinh
out_array = np.tanh(in_array)+ np.sinh(in_array)
sum_diff = np.diff(np.tanh(in_array))+np.diff(np.sinh(in_array))
# out_array = out_array1+ out_array2
diff_tanh=np.diff(out_array)
print("in_array : ", in_array)
print("\nout_array : ", diff_tanh)
  
# red for numpy.cosh()
plt.plot(in_array, out_array2 , color = 'orange', marker = "o", label = 'cosh')
plt.plot(in_array, out_array, label = 'sum tanh + sinh',color = 'red', marker = "o")
plt.plot(in_array[:-1], sum_diff, label = 'diffferential of sum of sinh+tanh',color = 'blue', marker = "o")
plt.title("sum of sinh+tanh")
# plt.plot(x, y, label = "line 1")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# in_array :  [-3.14159265 -2.86841068 -2.59522871 -2.32204674 -2.04886477 -1.7756828
#  -1.50250083 -1.22931886 -0.95613689 -0.68295492 -0.40977295 -0.13659098
#   0.13659098  0.40977295  0.68295492  0.95613689  1.22931886  1.50250083
#   1.7756828   2.04886477  2.32204674  2.59522871  2.86841068  3.14159265]
#
# out_array :  [2.77533043 2.11824678 1.62126246 1.24774633 0.97072475 0.77093242
#  0.63518248 0.55441113 0.52043918 0.5211182  0.53685334 0.54552785
#  0.53685334 0.5211182  0.52043918 0.55441113 0.63518248 0.77093242
#  0.97072475 1.24774633 1.62126246 2.11824678 2.77533043]

# %%
plt.plot(in_array, out_array, color = 'red', marker = "o")
plt.title("differential of sinh+tanh")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
